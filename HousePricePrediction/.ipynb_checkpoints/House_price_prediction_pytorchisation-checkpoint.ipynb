# %% [markdown]
# https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html

# %%
import torch
import pandas as pd
import numpy as np
import torch.distributions.exponential as dist
from scipy import stats
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("BostonHousing.csv")
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# correlation plotting: https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas

data.corr().style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_e2057_row0_col0, #T_e2057_row1_col1, #T_e2057_row2_col2, #T_e2057_row3_col3, #T_e2057_row4_col4, #T_e2057_row5_col5, #T_e2057_row6_col6, #T_e2057_row7_col7, #T_e2057_row8_col8, #T_e2057_row9_col9, #T_e2057_row10_col10, #T_e2057_row11_col11, #T_e2057_row12_col12, #T_e2057_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2057_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e2057_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_e2057_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e2057_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_e2057_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e2057_row0_col6, #T_e2057_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_e2057_row0_col7, #T_e2057_row11_col4, #T_e2057_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# ...

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.drop(columns=['chas', 'rad', 'zn'], inplace=True)

# %%
# Removing outliers which has z-score higher than 3
''' A z-score measures exactly how many standard deviations above or below the mean a data point is. '''
# https://stackoverflow.com/questions/23199796/detect-and-exclude-outliers-in-a-pandas-dataframe?answertab=modifieddesc#tab-top

data = data[np.abs(stats.zscore(data)) < 3]
data
# Out:
#         crim  indus    nox     rm   age     dis  tax  ptratio       b  lstat  \
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900  296     15.3  396.90   4.98
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671  242     17.8  396.90   9.14
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671  242     17.8  392.83   4.03
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622  222     18.7  394.63   2.94
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622  222     18.7  396.90   5.33
# ..       ...    ...    ...    ...   ...     ...  ...      ...     ...    ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786  273     21.0  391.99   9.67
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875  273     21.0  396.90   9.08
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675  273     21.0  396.90   5.64
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889  273     21.0  393.45   6.48
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050  273     21.0  396.90   7.88
#
#      medv
# 0    24.0
# 1    21.6
# ...

# %%
# Checking for NaN values in the DataFrame

data.isna().sum()
# Out:
# crim        8
# indus       0
# nox         0
# rm          8
# age         0
# dis         5
# tax         0
# ptratio     0
# b          25
# lstat       5
# medv        0
# dtype: int64

# %%
data = data.dropna()

data.isna().sum()
# Out:
# crim       0
# indus      0
# nox        0
# rm         0
# age        0
# dis        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64
